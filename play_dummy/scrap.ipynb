# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import os

os.chdir("..")

from play_dummy.objectives import prot_builder

# %%
f = prot_builder()
x = torch.rand(1,9)

f(x)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 f = prot_builder()
#       2 x = torch.rand(1,9)
# ----> 4 f(x)
#
# File ~/Projects/BO_Lichtenberg/PROTEUS/play_dummy/objectives.py:266, in J(x, true_y, parameters, out_scaler)
#     262 run_name = "BO/worker"
#     264 par = {parameters[i]: x[0, i].item() for i in range(len(parameters))}
# --> 266 sim = run_proteus(par, run_name, observables)
#     267 sim = torch.tensor(sim.values).reshape(1, -1)
#     268 sim = out_scaler.transform(sim)
#
# File ~/Projects/BO_Lichtenberg/PROTEUS/play_dummy/utils.py:60, in run_proteus(parameters, run_name, observables, ref_config, max_attempts)
#      57 for attempt in range(1, max_attempts+1):
#      58     try:
#      59         # create
# ---> 60         update_toml(ref_config, parameters, config_path)
#      62         # Run the simulator as a subprocess
# ...
