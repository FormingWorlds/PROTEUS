# %%
import pandas as pd

# %%
labels = ["sd", "fs", "L"]
x = [2,1,6]

dat =pd.Series(x, labels)

dat["a"] = 0.5

dat, dat.to_list()
# Out:
# (sd    2.0
#  fs    1.0
#  L     6.0
#  a     0.5
#  dtype: float64,
#  [2.0, 1.0, 6.0, 0.5])

# %%
observables = [ "z_obs",
                "R_int",
                "M_planet",
                "transit_depth",
                "bond_albedo",
                "contrast_ratio"]

#observables.append("index")

y = ["index"].append(observables)
print(y)
# Out:
# None
